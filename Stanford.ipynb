# %%
# !stanford-parser-full-2020-11-17/lexparser.sh ./raw.txt
# Out:
# [main] INFO edu.stanford.nlp.parser.lexparser.LexicalizedParser - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ... done [0.7 sec].
# Parsing file: ./raw.txt
# Parsing [sent. 1 len. 10]: The old car broke down in the car park .
# (ROOT
#   (S
#     (NP (DT The) (JJ old) (NN car))
#     (VP (VBD broke)
#       (PRT (RP down))
#       (PP (IN in)
#         (NP (DT the) (NN car) (NN park))))
#     (. .)))
#
# det(car-3, The-1)
# amod(car-3, old-2)
# nsubj(broke-4, car-3)
# root(ROOT-0, broke-4)
# compound:prt(broke-4, down-5)
# case(park-9, in-6)
# det(park-9, the-7)
# compound(park-9, car-8)
# obl:in(broke-4, park-9)
#
# Parsing [sent. 2 len. 11]: At least two men broke in and stole my TV .
# (ROOT
#   (S
#     (NP
#       (QP
#         (ADVP (IN At) (JJS least))
#         (CD two))
#       (NNS men))
#     (VP
#       (VP (VBD broke)
#         (PRT (RP in)))
#       (CC and)
#       (VP (VBD stole)
#         (NP (PRP$ my) (NN TV))))
# ...
